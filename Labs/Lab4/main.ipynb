# %%
import utils

# %%
mean = [2, 2]
cov = [[10, 0], [0, 0.1]]
x = utils.generate_data(mean, cov, n=100)
utils.scatter_pca_2D(x)

# %%
mean = [1, 2, 3]
cov = [[0.1, 0, 0], [0, 10, 0], [0, 0, 10]]
x = utils.generate_data(mean, cov, n=100)
utils.scatter_pca_3D(x)

# %%
k_list = [50, 10, 5, 3, 1]
utils.faces_pca('faces', k_list)
